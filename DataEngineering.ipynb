# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !pwd
# Out:
# /content

# %%
# %cd sample_data/
# Out:
# /content/sample_data

# %%
df = pd.read_csv('/content/drive/MyDrive/test/2022_02_08-02_30_31_AM.csv')

# %%
df.head()
# Out:
#                                    uuid price_string price_string_unf  \
# 0  638744a4-b0ae-4166-8cb6-5c063c862036          NaN              NaN
# 1  ab313969-02cc-48b2-9daf-0054efb70b92          NaN              NaN
# 2  acbd66ff-79f8-467a-91f9-108a45af5626       $19.95              NaN
# 3  963915d6-b2e3-4098-b242-9410593cf205       $92.00              NaN
# 4  b5b68f3c-b1e0-40e5-8ee5-e2f7236c1daf        11.50              NaN
#
#                                         product_type  \
# 0                           TGFwdG9wIENvdmVycy9CYWdz
# 1                        QmFraW5nIEN1cHMgYW5kIE1hdHM
# 2  R3VtbWllcyB2aXRhbWlucyBhbmQgbWluZXJhbHMgZm9yIG...
# 3                                           U2VydW1z
# 4                    RWF0aW5nIFV0ZW5zaWxzL0N1dGxlcnk
#
#                               level_1                          category
# 0                     TGFwdG9wIENhc2U                   RWxlY3Ryb25pY3M
# 1  QmFraW5nIE1hdHMgLyBCYWtpbmcgZGlzaA        a2l0Y2hpbmcgYW5kIGRpbmluZw
# ...

# %%
# 1- Products without prices
#Here I am taking the intersection of two column and showing the product price result

# %%
df1 = df[df['price_string'].isnull()& (df['price_string_unf'].isnull())]  
df1
# Out:
#                                           uuid price_string price_string_unf  \
# 0         638744a4-b0ae-4166-8cb6-5c063c862036          NaN              NaN
# 1         ab313969-02cc-48b2-9daf-0054efb70b92          NaN              NaN
# 5         389d9f75-cc3f-4bd2-94f7-93e381a3bed5          NaN              NaN
# 13        1f2766ec-0a27-43f8-b28b-77a44492ead1          NaN              NaN
# 16        7bad39f5-74b9-4611-afb9-46fb135190cd          NaN              NaN
# ...                                        ...          ...              ...
# 13729992  8d763911-79b7-402d-8964-6bfe89692c66          NaN              NaN
# 13729993  2dc182aa-d591-49e4-85d1-5c4a60a09664          NaN              NaN
# 13729995  2a13338e-9268-4f7b-9e7c-b8c41c72971b          NaN              NaN
# 13729997  679f073a-862a-4e43-b5ce-41e45afd3bfa          NaN              NaN
# 13729998  25677eee-c26b-4abf-bd10-ca77a800ba26          NaN              NaN
#
# ...

# %%
#2- Count of products without prices and with prices in each Product Type, Category, Level 1
# Here I used same above code to calculate non price products and price product

# %%
# Product with prices
df2 = df[df['price_string'].isnull()==False & (df['price_string_unf'].isnull()==False)]

# %%
df2
# Out:
#                                           uuid price_string price_string_unf  \
# 2         acbd66ff-79f8-467a-91f9-108a45af5626       $19.95              NaN
# 3         963915d6-b2e3-4098-b242-9410593cf205       $92.00              NaN
# 4         b5b68f3c-b1e0-40e5-8ee5-e2f7236c1daf        11.50              NaN
# 6         9599f1a9-d406-43eb-89f5-9b1c0af1ac9a       $24.99              NaN
# 7         35799087-f6f4-4ca2-abfe-cbb5c27d2f1a      $148.00              NaN
# ...                                        ...          ...              ...
# 13729987  e12c3fe8-2987-4e95-93b2-14e173d8028a       $32.99              NaN
# 13729989  544416c3-4845-4427-b27b-d3ca9beca970       $34.00              NaN
# 13729994  f0ec31d4-3283-4931-af8b-6fb9fdb8b1aa       $86.00              NaN
# 13729996  fcaedae7-dc20-4da1-b4ae-77368c973088       $69.99              NaN
# 13729999  0f4550de-1f33-48b5-a5ef-fc5e39df208e       $55.00              NaN
#
# ...

# %%
 # product without prices
 df1
# Out:
#                                           uuid  price_string price_string_unf  \
# 0         638744a4-b0ae-4166-8cb6-5c063c862036           NaN              NaN
# 1         ab313969-02cc-48b2-9daf-0054efb70b92           NaN              NaN
# 5         389d9f75-cc3f-4bd2-94f7-93e381a3bed5           NaN              NaN
# 13        1f2766ec-0a27-43f8-b28b-77a44492ead1           NaN              NaN
# 16        7bad39f5-74b9-4611-afb9-46fb135190cd           NaN              NaN
# ...                                        ...           ...              ...
# 13729992  8d763911-79b7-402d-8964-6bfe89692c66           NaN              NaN
# 13729993  2dc182aa-d591-49e4-85d1-5c4a60a09664           NaN              NaN
# 13729995  2a13338e-9268-4f7b-9e7c-b8c41c72971b           NaN              NaN
# 13729997  679f073a-862a-4e43-b5ce-41e45afd3bfa           NaN              NaN
# 13729998  25677eee-c26b-4abf-bd10-ca77a800ba26           NaN              NaN
#
# ...

# %%
# 3-Correct Product Prices in the correct format (eg: $56) wherever possible and separate them into currency and value columns
# here I am gonna use only price_string columns

# %%
# seeing the unique values in column
df2['price_string'].unique()
# Out:
# array(['$19.95', '$92.00', '11.50', '$24.99', '$148.00', '$89', '$14.95',
#        '$55.00', '32.99', '52.00', '$11.30', '$13.99', '$6.95', '$0.00',
#        '$129', '$10.99', '$6.49', '$18.99', '$179', '$9.99', '$3.99',
#        '$549', '$16.99', '$49.99', '$90.00', '$12.99', '$59', '$85.00',
#        '$128.00', '$150', '$6.99', '$34.00', '$248.00', '$4.99', '$65',
#        '11.00', '$459', '$199', '14.95', '$135.05', '$1099', '$7.97',
#        '$6.75', '$15.00', '$5.29', '$10.00', '7.00', '$80.00', '$2.29',
#        '$119', '6.60', '$399', '$39.95', '12.00', '$8.99', '$79', '$35',
#        '$34.95', '$99', '$18.95', '$459.99', '$58.00', '$25.70', '$3.50',
#        '$619.00', '$95', '$159', '$45', '$149', '$85', '$8.95', '$69',
#        '$14.00', '$38.00', '$6.50', '$12.50', '$24.00', '$27.00',
#        '$82.75', '$9.95', '$26.96', '$17.96', '$15.99', '$6.17', '$75',
#        '$250', '$29.00', '$1198', '$18.00', '$45.00', '$44.00', '$14.99',
# ...

# %%
for i in df2['price_string'].unique():
  if i[0]!='$':
    df2.loc[df2[df2['price_string']==i].index,'price_string']='$'+i
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
# now values has been modified in this manner '$45'
df2['price_string'].unique()
# Out:
# array(['$19.95', '$92.00', '$11.50', '$24.99', '$148.00', '$89', '$14.95',
#        '$55.00', '$32.99', '$52.00', '$11.30', '$13.99', '$6.95', '$0.00',
#        '$129', '$10.99', '$6.49', '$18.99', '$179', '$9.99', '$3.99',
#        '$549', '$16.99', '$49.99', '$90.00', '$12.99', '$59', '$85.00',
#        '$128.00', '$150', '$6.99', '$34.00', '$248.00', '$4.99', '$65',
#        '$11.00', '$459', '$199', '$135.05', '$1099', '$7.97', '$6.75',
#        '$15.00', '$5.29', '$10.00', '$7.00', '$80.00', '$2.29', '$119',
#        '$6.60', '$399', '$39.95', '$12.00', '$8.99', '$79', '$35',
#        '$34.95', '$99', '$18.95', '$459.99', '$58.00', '$25.70', '$3.50',
#        '$619.00', '$95', '$159', '$45', '$149', '$85', '$8.95', '$69',
#        '$14.00', '$38.00', '$6.50', '$12.50', '$24.00', '$27.00',
#        '$82.75', '$9.95', '$26.96', '$17.96', '$15.99', '$6.17', '$75',
#        '$250', '$29.00', '$1198', '$18.00', '$45.00', '$44.00', '$14.99',
# ...

# %%
df2['price'] = df2['price_string']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for i in df2['price_string'].unique():
  if i[0]=='$':
    df2.loc[df2[df2['price']==i].index,'price']=float(i[1:])
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
#4-List out the categories with average price of product
# here we are importing numpy for taking mean
import numpy as np
average = np.mean(df2['price'])
average
# Out:
# 70.02898366696627

# %%
# here is the column for average price of the product with categories
df2[df2['price']==70.00]
# Out:
#                                           uuid price_string price_string_unf  \
# 473       983b2530-c0ba-4063-867d-6aea30521f9e       $70.00              NaN
# 2410      983b2530-c0ba-4063-867d-6aea30521f9e       $70.00              NaN
# 5373      983b2530-c0ba-4063-867d-6aea30521f9e       $70.00              NaN
# 6322      983b2530-c0ba-4063-867d-6aea30521f9e       $70.00              NaN
# 11784     983b2530-c0ba-4063-867d-6aea30521f9e       $70.00              NaN
# ...                                        ...          ...              ...
# 13723976  983b2530-c0ba-4063-867d-6aea30521f9e       $70.00              NaN
# 13725880  983b2530-c0ba-4063-867d-6aea30521f9e       $70.00              NaN
# 13727397  983b2530-c0ba-4063-867d-6aea30521f9e       $70.00              NaN
# 13727639  983b2530-c0ba-4063-867d-6aea30521f9e       $70.00              NaN
# 13729356  983b2530-c0ba-4063-867d-6aea30521f9e       $70.00              NaN
#
# ...
